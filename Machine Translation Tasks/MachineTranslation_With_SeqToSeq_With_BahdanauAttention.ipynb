# %%
import pandas as pd
import torch
import torch.nn as nn
import re
from collections import Counter
import numpy as np
import random
from torch.utils.data import Dataset, DataLoader, random_split
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence,pack_padded_sequence, pad_packed_sequence
import os
seed = 1234

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

#path = r'/kaggle/input/eng-french/eng_french.csv'
path = r'C:\Users\harish-4072\Downloads\eng_french.csv'
df = pd.read_csv(path, names=['English','French'], header=0)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def preprocess_text(text):
    text = text.lower()  
    text = re.sub(r'[^a-z\s]', '', text)  
    tokens = text.split()  
    return tokens

def tokenize_text(tokens,token_to_id):
    tokens = [token_to_id.get(token,0) for token in tokens]
    return [1] + tokens + [2]

def tokenize_text_without_special_tkns(tokens,token_to_id):
    return [token_to_id.get(token,0) for token in (tokens)]
    
english_sentences = df['English'].dropna().apply(preprocess_text)
french_sentences = df['French'].dropna().apply(preprocess_text)
english_vocab = Counter([token for sentence in english_sentences for token in sentence])
french_vocab = Counter([token for sentence in french_sentences for token in sentence])
english_token_to_id = {token: idx + 1 for idx, token in enumerate(english_vocab)}  
french_token_to_id = {token: idx + 3 for idx, token in enumerate(french_vocab)}

english_token_to_id['<PAD>'] = 0
french_token_to_id['<PAD>'] = 0
french_token_to_id['<SOS>'] = 1
french_token_to_id['<EOS>'] = 2
french_id_to_token= {value:key for key,value in french_token_to_id.items()}
english_vocab_size = len(english_token_to_id)
french_vocab_size = len(french_token_to_id)
english_sequences = english_sentences.apply(lambda x: tokenize_text_without_special_tkns(x, english_token_to_id))
french_sequences = french_sentences.apply(lambda x: tokenize_text(x, french_token_to_id))

# %%
class SentencesDataset(Dataset):
    def __init__(self,english_sequences,french_sequences):
        self.english_sequences = english_sequences
        self.french_sequences = french_sequences
        assert len(self.english_sequences) == len(self.french_sequences)

    def __len__(self):
        return len(self.english_sequences)

    def __getitem__(self,idx):
        X= self.english_sequences[idx]
        y= self.french_sequences[idx]
        return torch.tensor(X,dtype=torch.long).to(device),torch.tensor(y,dtype=torch.long).to(device)

# %%
def collate_fn(batch):
    X,y = zip(*batch)
    X_lengths = [len(item) for item in X]
    y_lengths = [len(item) for item in y]
    X_padded = pad_sequence(X, batch_first=True, padding_value=0)
    y_padded = pad_sequence(y, batch_first=True, padding_value=0)
    return X_padded, y_padded, X_lengths, y_lengths

# %%
english_temp, french_temp = english_sequences[:1000].reset_index(drop=True), french_sequences[:1000].reset_index(drop=True)

# %%
dataset = SentencesDataset(english_temp,french_temp)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True,collate_fn = collate_fn)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False,collate_fn = collate_fn)

# %%
EMBEDDING_DIM = 30
HIDDEN_DIM = 128
NUM_LAYERS = 1
DROPOUT = 0.3
SRC_VOCAB_SIZE = english_vocab_size  
PAD_IDX = 0 
TRG_VOCAB_SIZE = french_vocab_size

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hidden_dim, num_layers, dropout,padding_idx):
        super(Encoder, self).__init__()
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim, hidden_dim, num_layers=num_layers, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim*2,hidden_dim)

    def forward(self, src):
        #src - batch*l
        #embedded - batch*l*embedding
        #outputs - batch*l*hidden_dim*2
        #final_hidden - 1*batch*hidden_dim (same as decoder GRU hidden size)
        embedded = self.dropout(self.embedding(src)) 
        outputs, hidden = self.rnn(embedded) 
        final_hidden = torch.tanh(
            self.fc(torch.cat((hidden[-2, :, :], hidden[-1, :, :]), dim=1))
        )
        return outputs, final_hidden.unsqueeze(0)

# %%
class BahdanauAttention(nn.Module):
    
    def __init__(self, encoder_hdim, decoder_hdim):
        super(BahdanauAttention, self).__init__()
        self.linear = nn.Linear((encoder_hdim*2)+decoder_hdim, decoder_hdim)
        self.fc = nn.Linear(decoder_hdim,1,bias=False)

    def forward(self, encoder_outputs, decoder_hidden):
        #et​=vTtanh(W[hs​;st−1​])
        
        #encoder_outputs - batch*l*hidden_dim*2
        #decoder_hidden - 1*batch*hidden_dim 
        #decoder_hidden_expanded - batch*l*hidden_dim
        #a - batch*l* hidden_dim*2+hidden_dim
        #energy - batch*l*hidden_dim
        #output - batch*l*1
        src_len = encoder_outputs.shape[1]
        decoder_hidden = decoder_hidden.permute(1,0,2)
        decoder_hidden_expanded = decoder_hidden.repeat(1, src_len, 1)  
        weighted = torch.cat([decoder_hidden_expanded,encoder_outputs], dim=-1)
        attention_weights = torch.tanh(self.linear(weighted))
        return torch.softmax(self.fc(attention_weights),dim=1)

# %%
class BahdanauAttention2(nn.Module):
    def __init__(self, encoder_hdim, decoder_hdim, attention_weight):
        super(BahdanauAttention2, self).__init__()
        self.Wa = nn.Linear((encoder_hdim*2), attention_weight)
        self.Ua = nn.Linear(decoder_hdim, attention_weight)
        self.fc = nn.Linear(attention_weight,1,bias=False)

    def forward(self, encoder_outputs, decoder_hidden):
        #et​=vTtanh(Wa​hs​+Ua​st−1​)
        #encoder_outputs - batch*l*hidden_dim*2
        #decoder_hidden - 1*batch*hidden_dim 
        #a - batch*l* hidden_dim*2+hidden_dim
        #energy - batch*l*hidden_dim
        #output - batch*l*1
        src_len = encoder_outputs.shape[1]
        decoder_hidden = decoder_hidden.permute(1,0,2)
        weighted = torch.tanh(self.Wa(encoder_outputs) + self.Ua(decoder_hidden))
        attention_weights = self.fc(weighted)
        return torch.softmax(self.fc(attention_weights),dim=1)

# %%
class Decoder(nn.Module):
    def __init__(self,output_dim, emb_dim, encoder_hdim, decoder_hdim,dropout = 0.5):
        super(Decoder, self).__init__()
        self.output_dim = output_dim
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.attention = attention
        self.rnn = nn.GRU(emb_dim+(encoder_hdim*2), decoder_hdim, batch_first=True, bidirectional=False)
        self.fc = nn.Linear((decoder_hdim+(encoder_hdim*2)+emb_dim),output_dim)
        self.dropout = nn.Dropout(dropout)
    def forward(self, src, encoder_outputs, hidden):
        #src = batch
        #encoder_outputs - batch*l*hidden_dim*2
        #hidden - 1*batch*hidden_dim 
        #embedded = batch*1*emd_dim
        #attention_weights - batch*l*1
        #weighted - batch*1*hidden_dim*2
        #energy = batch*1*emd_dim.cat(batch*1*hidden_dim*2) = batch*1*(emd_dim+hidden_dim*2)
        #output, hidden = batch * 1 * hidden_dim
        #torch.cat((output,embedded,weighted.permute(0,2,1)) = batch*1*hidden_dim+(hidden_dim*2)+emb_dim
        #predictions = batch*1*target_vocab_size
        #hidden = 1*batch*hidden_dim
        embedded = self.dropout(self.embedding(src.unsqueeze(1)))
        attn_weights = self.attention(encoder_outputs, hidden)
        weighted = torch.bmm(attn_weights.permute(0,2,1),encoder_outputs)
        rnn_input  = torch.cat((embedded,weighted),dim=2)
        output,hidden = self.rnn(rnn_input ,hidden)
        predictions = self.fc(torch.cat((output,embedded,weighted),dim=2))
        return predictions.squeeze(1), hidden

# %%
class SeqToSeq(nn.Module):
    def __init__(self, encoder, decoder):
        super(SeqToSeq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, src, trg, teacher_forcing_ratio):
        #src = batch*l
        #trg = batch*MAX_LENGTH
        #src_len = batch*l
        #encoder_outputs - batch*l*hidden_dim*2
        #hidden - 1*batch*hidden_dim 
        #outputs - batch*MAX_LENGTH*TRG_VOCAB_SIZE
        #input - batch
        batch_size = src.shape[0]
        trg_len = trg.shape[1]
        encoder_outputs, hidden = self.encoder(src)
        outputs = torch.zeros(batch_size, trg_len, TRG_VOCAB_SIZE)
        input = trg[:, 0]
        for t in range(1,trg_len):
            #predictions - batch*1*target_vocab_size
            #hidden - 1*batch*hidden_dim
            #outputs - batch*MAX_LENGTH*TRG_VOCAB_SIZE
            #top1, input - batch
            predictions, hidden = self.decoder(input, encoder_outputs, hidden)
            outputs[:, t, :] = predictions  
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = predictions.argmax(1) 
            input = trg[:, t] if teacher_force else top1
        return outputs

# %%
encoder = Encoder(
    input_dim=SRC_VOCAB_SIZE,
    emb_dim=EMBEDDING_DIM,
    hidden_dim=HIDDEN_DIM,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT,
    padding_idx = 0
)

# %%
attention = BahdanauAttention(
    encoder_hdim= HIDDEN_DIM, 
    decoder_hdim=HIDDEN_DIM
)

# %%
# for X, y,_,_ in train_loader:
#     outputs, hidden = encoder(X)
# print(outputs.shape, hidden.shape)
# print(attention(outputs,hidden).shape)
# input = torch.randint(0, 100, (1,32))
# input.squeeze(0).shape
# a,b = decoder(input.squeeze(0), outputs,hidden)
# a.shape,b.shape

# %%
decoder = Decoder(
    output_dim=TRG_VOCAB_SIZE,
    emb_dim=EMBEDDING_DIM,
    encoder_hdim=HIDDEN_DIM,
    decoder_hdim=HIDDEN_DIM,
    dropout = 0.5
)

# %%
model = SeqToSeq(encoder, decoder).to(device)
if os.path.exists("seq2seq_model_weights_attention.pth"):
    model.load_state_dict(torch.load("seq2seq_model_weights_attention.pth"))
# Out:
# C:\Users\harish-4072\AppData\Local\Temp\ipykernel_44988\93205287.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("seq2seq_model_weights_attention.pth"))

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


print(f"The model has {count_parameters(model):,} trainable parameters")
# Out:
# The model has 13,284,308 trainable parameters

# %%
EPOCHS = 7
LEARNING_RATE = 0.01

# %%
optimizer = optim.Adam(model.parameters())
criterion = nn.CrossEntropyLoss(ignore_index=PAD_IDX)

# %%
for epoch in range(EPOCHS):
    model.train()
    epoch_loss = 0
    for src, trg, src_lengths,_ in train_loader:
        optimizer.zero_grad()
        output = model(src, trg,  0.5).to(device)
        output = output[:, 1:].reshape(-1, output.shape[-1])  
        trg = trg[:, 1:].reshape(-1)
        loss = criterion(output, trg)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        epoch_loss += loss.item()
        torch.save(model.state_dict(), "seq2seq_model_weights_attention.pth")
    print(f"Epoch: {epoch + 1}/{EPOCHS}, Loss: {epoch_loss / len(train_loader):.4f}")
# Out:
# Epoch: 1/7, Loss: 9.5727
# Epoch: 2/7, Loss: 8.4130
# Epoch: 3/7, Loss: 6.7398
# Epoch: 4/7, Loss: 5.3072
# Epoch: 5/7, Loss: 4.7187
# Epoch: 6/7, Loss: 4.5389
# Epoch: 7/7, Loss: 4.4294

# %%
model.eval()
epoch_loss = 0

with torch.no_grad():
    for src, trg, src_lengths, _ in val_loader:
            
        output = model(src, trg, teacher_forcing_ratio=0.5).to(device)
        output = output[:, 1:].reshape(-1, output.shape[-1])  # Ignore <sos> token
        trg = trg[:, 1:].reshape(-1)

        loss = criterion(output, trg)
        epoch_loss += loss.item()

    print(epoch_loss / len(val_loader))
# Out:
# 5.460605621337891

# %%
def infer(model, src,french_token_to_id, max_len=50):
    
    model.eval()
    with torch.no_grad():
        encoder_outputs, hidden = model.encoder(src)

        # Start with <sos> token
        trg_vocab_size = TRG_VOCAB_SIZE
        input = torch.tensor([1], device=device)
        predictions = []

        for _ in range(max_len):
            output, hidden = model.decoder(input, encoder_outputs, hidden)
            top1 = output.argmax(1)  # Get the token with highest probability
            predictions.append(top1.item())
            print(top1)
            if top1.item() == french_token_to_id['<EOS>']:
                break

            input = top1.to(device)  # Use the predicted token as input for the next step
    return [french_id_to_token[idx] for idx in predictions]

# %%
sentence = "I like you"
sentence = preprocess_text(sentence)
sentence = tokenize_text(sentence, english_token_to_id)
output = infer(model, torch.tensor([sentence]).to(device),french_token_to_id)
# Out:
# tensor([22])
# tensor([2])

# %%
output
# Out:
# ['je', '<EOS>']

# %%
import re

def read_properties(file_path):
    """Reads a properties file and returns a list of (key, value) tuples."""
    props = []
    with open(file_path, "r", encoding="utf-8") as file:
        for line in file:
            line = line.strip()
            if line and not line.startswith("#"):
                key, value = re.split(r"\s*[:=]\s*", line, 1)
                props.append((key.strip(), value.strip()))
    return props

# %%
props = read_properties(r'C:\Users\harish-4072\Pictures\ApplicationResources.properties')

# %%
updates = props[:10]

# %%
updates
# Out:
# [('dc.db.agent.patchinstall.fail', 'Failed Patch Deployments'),
#  ('dc.patch.homepage.Patch_SeveritySummary', 'Patch Severity Summary'),
#  ('dc.patch.xml.No_Results_matching_this_criteria', 'No data found.'),
#  ('vmp.common.professional_no_permission',
#   'You do not have enough permission to perform this action. Upgrade to Enterprise Edition to use these features.'),
#  ('dc.common.INFO', 'Info'),
#  ('dc.common.VULN_SETTINGS', 'Vulnerability Settings'),
#  ('dc.pm.msg.sync_failed_title', 'Vulnerability DB Sync Failed!'),
#  ('dc.privacy.vmp_return', 'Start using Vulnerability Manager'),
#  ('dc.common.vmp.website', 'http://www.vulnerabilitymanagerplus.com'),
#  ('dc.admin.title.dc_server_migration', 'Central Server Migration')]

# %%
def update_properties(props, updates):
    updated_props = []
    seen_keys = set()
    for key, value in reversed(props):  
        if key in updates:
            if key not in seen_keys:
                updated_props.append((key, updates[key]))
                seen_keys.add(key)
        else:
            updated_props.append((key, value))
    return list(reversed(updated_props))

# %%
def write_properties(file_path, props):
    with open(file_path, "w", encoding="utf-8") as file:
        for key, value in props:
            file.write(f"{key}={value}\n")

# %%
write_properties(path, update_properties(props, updates))

# %%
update_properties(props, updates)
# Out:
# [('dc.db.agent.patchinstall.fail', 'Failed Patch Deployments'),
#  ('dc.patch.homepage.Patch_SeveritySummary', 'Patch Severity Summary'),
#  ('dc.patch.xml.No_Results_matching_this_criteria', 'No data found.'),
#  ('vmp.common.professional_no_permission',
#   'You do not have enough permission to perform this action. Upgrade to Enterprise Edition to use these features.'),
#  ('dc.common.INFO', 'Info'),
#  ('dc.common.VULN_SETTINGS', 'Vulnerability Settings'),
#  ('dc.pm.msg.sync_failed_title', 'Vulnerability DB Sync Failed!'),
#  ('dc.privacy.vmp_return', 'Start using Vulnerability Manager'),
#  ('dc.common.vmp.website', 'http://www.vulnerabilitymanagerplus.com'),
#  ('dc.admin.title.dc_server_migration', 'Central Server Migration'),
#  ('vulnerbility.addon.title', 'Vulnerability'),
#  ('dc.genProp.vmp.supportMail',
#   'vulnerabilitymanagerplus-support@manageengine.com'),
#  ('dc.genProp.vmp.renewalMail', 'vmp-renewals@manageengine.com'),
#  ('dc.genProp.vmp.request_demo',
#   'http://www.manageengine.com/vulnerability-management/request-demo.html'),
#  ('dc.genProp.vmp.request_support',
#   'http://www.manageengine.com/vulnerability-management/request-support.html'),
#  ('dc.genProp.vmp.feature_request',
#   'http://www.manageengine.com/vulnerability-management/need-features.html'),
#  ('dc.genProp.vmp.forums',
#   'https://forums.manageengine.com/vulnerability-manager-plus'),
#  ('dc.genProp.vmp.newtopic',
#   'https://forums.manageengine.com/vulnerability-manager-plus/newtopic'),
#  ('dc.genProp.vmp.store',
#   'http://store.manageengine.com/vulnerability-management/'),
#  ('dc.genProp.vmp.vmp_today',
#   'http://www.manageengine.com/vulnerability-management/service-packs.html'),
#  ('dc.genProp.vmp.faq',
#   'http://www.manageengine.com/vulnerability-management/help/faq.html'),
#  ('dc.genProp.vmp.kb',
#   'http://www.manageengine.com/vulnerability-management/knowledge-base/index.html'),
#  ('dc.genProp.vmp.get_quote',
#   'http://www.manageengine.com/vulnerability-management/get-quote.html?vmpi'),
#  ('dc.genProp.vmp.user_guide',
#   'http://www.manageengine.com/vulnerability-management/help/index.html'),
#  ('dc.genProp.vmp.download',
#   'http://www.manageengine.com/vulnerability-management/download.html'),
#  ('dc.genProp.vmp.help',
#   'http://www.manageengine.com/vulnerability-management/help'),
#  ('dc.admin.vmp.license.customer.thanks.url',
#   'http://www.manageengine.com/vulnerability-management/thanks.html'),
#  ('dc.admin.vmp.license.getextention.url',
#   'http://www.manageengine.com/vulnerability-management/request-license.html?subject=Request%20Additional%20User%20License%20Extension&expiry={0}'),
#  ('dc.admin.vmp.updates_check_url',
#   'https://patchdb.manageengine.com/crs/vmpupdates.json'),
#  ('dc.common.vmp.website.architecture.lan',
#   'https://www.manageengine.com/vulnerability-management/images/vmp-architecture.png'),
#  ('dc.common.vmp.website.architecture.wan',
#   'https://www.manageengine.com/vulnerability-management/images/vmp-architecture-wan.png'),
#  ('dc.common.vmp.website.customers',
#   'http://www.manageengine.com/vulnerability-management/customers.html'),
#  ('dc.common.vmp.website.customer_quote',
#   'http://www.manageengine.com/vulnerability-management/customer-quotes.html'),
#  ('dc.common.vmp.website.casestudy',
#   'http://www.manageengine.com/vulnerability-management/patchmanagerplus-case-study.html'),
#  ('dc.common.vmp.website.sys_req',
#   'http://www.manageengine.com/vulnerability-management/system-requirements.html'),
#  ('dc.common.vmp.website.adminguide.pdf',
#   'http://www.manageengine.com/vulnerability-management/pmp-admin-guide.pdf'),
#  ('dc.common.vmp.website.userguide.pdf',
#   'http://www.manageengine.com/vulnerability-management/pmp-user-guide.pdf'),
#  ('dc.common.vmp.website.features',
#   'http://www.manageengine.com/vulnerability-management/features.html'),
#  ('dc.common.vmp.website.architecture',
#   'https://www.manageengine.com/vulnerability-management/help/vulnerability-management-architecture.html'),
#  ('dc.common.website.bsp',
#   'https://www.manageengine.com/secure-browser/?vmplogin'),
#  ('dc.patch.updatedb.Failed_to_Update_the_CIS_1',
#   'Failed to Update the CIS DataBase due to {0}'),
#  ('vmp.admin.login.demo.caption',
#   'Integrated Threat and Vulnerability Management'),
#  ('vmp.admin.login.demo.description',
#   'Vulnerability Manager Plus is a multi-OS vulnerability management and compliance solution that offers built-in remediation.'),
#  ('vmp.antivirus.disabled', 'Antivirus Disabled'),
#  ('vmp.antivirus.missing', 'Antivirus Missing'),
#  ('vmp.antivirus.not_up_to_date', 'Antivirus Definitions not up-to-date'),
#  ('vmp.antivirus.secure', 'Antivirus Up-To-Date'),
#  ('vmp.antivirus.subtext.missing',
#   'Install third party antivirus to defend against malware and viruses'),
#  ('vmp.antivirus.subtext.not_up_to_date',
#   'Update the antivirus definitions to secure your network against latest malware attacks'),
#  ('vmp.antivirus.unknown_desc',
#   'Unable to detect antivirus presence, as the scan is not yet performed'),
#  ('vmp.antivirus.unknown_heading', 'Antivirus Status Unknown'),
#  ('vmp.antivirus.ANTIVIRUS_NAME', 'Antivirus Name'),
#  ('vmp.antivirus.ANTIVIRUS_LAST_UPDATED_TIME', 'Antivirus Last Updated Time'),
#  ('vmp.bitlocker.enabled', 'Bitlocker is Enabled'),
#  ('vmp.bitlocker.not_applicable', 'Bitlocker not available for this OS'),
#  ('vmp.bitlocker.unknown', 'Unable to detect bitlocker'),
#  ('vmp.bitlocker.unknown_desc',
#   'Unable to detect bitlocker presence, as the scan is not yet performed'),
#  ('vmp.bitlocker.unknown_heading', 'Bitlocker Status Unknown'),
#  ('vmp.common.ATTENTION_REQD', 'Attention Required'),
#  ('vmp.common.msg.Decline_Threats_title', 'Introducing threat exceptions'),
#  ('vmp.common.msg.Decline_Threats_content',
#   'Now you can add exceptions for vulnerabilities, misconfigurations and other threats from respective views.'),
#  ('vmp.common.ADDED_DATE', 'Added Date'),
#  ('vmp.common.CATEGORY', 'Category'),
#  ('vmp.common.creation_time', 'Creation time'),
#  ('vmp.common.last_modified', 'Last Modified'),
#  ('vmp.common.CAUTION', 'Post Deployment Issues'),
#  ('vmp.common.COMPLIANCE_SCANNING_FAILED', 'Scan Failed'),
#  ('vmp.common.COMPLIANCE_SCANNING_IN_PROGRESS', 'Scan In Progress'),
#  ('vmp.common.COMPLIANCE_SCANNING_COMPLETED', 'Scan Completed'),
#  ('vmp.common.COMPLIANCE_NOT_SCANNED', 'Yet to Scan'),
#  ('vmp.common.DATABASE_SERVER', 'Database Server'),
#  ('vmp.common.DB_VULNERABILITY_COUNT', 'DB Vulnerability Count'),
#  ('vmp.common.DEPLOYACTION', 'Action'),
#  ('vmp.common.DELETE', 'Delete'),
#  ('vmp.common.DEPLOYED_FIXES', 'Deployed Security Configurations'),
#  ('vmp.common.DESCRIPTION', 'Description'),
#  ('vmp.common.DISCOVERED_DATE', 'Discovered Date'),
#  ('vmp.common.exclusion', 'Add Exceptions'),
#  ('vmp.common.remove_exclusion', 'Remove Exceptions'),
#  ('vmp.common.decline_vuln', 'Excluded Vulnerabilities'),
#  ('vmp.common.decline_server_vuln', 'Excluded Server Vulnerabilities'),
#  ('vmp.common.decline_app', 'Excluded Risky Software'),
#  ('vmp.common.decline_misconfig', 'Excluded Misconfiguration'),
#  ('vmp.common.decline_hardening', 'Excluded Hardening'),
#  ('vmp.common.DECLINED_TIME', 'Excluded Time'),
#  ('vmp.common.DECLINE', 'Decline'),
#  ('vmp.common.EXCLUSION_GROUP_NAME', 'Custom Group'),
#  ('vmp.common.EXCLUSION_DESC', 'Reason for exclusion'),
#  ('vmp.common.EXCEPTION_TYPE', 'Exception Type'),
#  ('vmp.common.EXPLOIT_STATUS', 'Exploit Status'),
#  ('vmp.common.FIX', 'Fix'),
#  ('vmp.common.FIX_STATUS', 'Fix Status'),
#  ('vmp.common.fixable', 'Fixable'),
#  ('vmp.common.HARDENINGID', 'Hardening ID'),
#  ('vmp.common.INFO', 'Info'),
#  ('vmp.common.manual_fix', 'Manual Fix'),
#  ('vmp.common.MISCONFIGID', 'Misconfiguration ID'),
#  ('vmp.common.MISCONFIGURATION', 'Misconfiguration'),
#  ('vmp.common.MISCONFIGURATIONS', 'Misconfigurations'),
#  ('vmp.common.NO_THREATS_EXEMPTED', 'No exceptions have been defined'),
#  ('vmp.common.MANAGE_EXCEPTIONS_HOW_TO_LINK',
#   'How to add or remove threat and vulnerability exceptions?'),
#  ('vmp.common.NO_DECLINED_VULNS', 'No Vulnerabilities are excluded'),
#  ('vmp.common.NO_DECLINED_MCS', 'No Misconfigurations are excluded'),
#  ('vmp.common.NO_DECLINED_HARDENINGS',
#   'No Web server misconfigurations are excluded'),
#  ('vmp.common.NO_DECLINED_APPLICATIONS', 'No Applications are excluded'),
#  ('vmp.common.MISCONFIGURATION_REPORT', 'Misconfiguration Report'),
#  ('vmp.common.NO_DYNAMIC_THREATS',
#   'No Zero-Day vulnerabilities found on the specified criteria'),
#  ('vmp.common.NO_FAILED_MCS', 'No misconfiguration fix has been failed'),
#  ('vmp.common.NO_FIXED_MCS', 'No fixes have been deployed yet'),
#  ('vmp.common.NO_MANAGED_SYSTEMS',
#   'Install agents in your endpoints, to detect, analyze, fix and manage your network systems'),
#  ('vmp.common.NO_REPORTS_GENERATED', 'No reports generated'),
#  ('vmp.common.NO_SUPPORTED_MCS',
#   'No security misconfigurations are detected on the specified criteria'),
#  ('vmp.common.NO_SUPPORTED_VULNS', 'No data found.'),
#  ('vmp.common.NO_SW_UNINSTALL', 'No software have been uninstalled yet'),
#  ('vmp.common.NO_WEB_HARDENINGS',
#   'No web server misconfigurations are detected on the specified criteria'),
#  ('vmp.common.NO_OPEN_PORTS', 'No used ports have been identified as yet'),
#  ('vmp.common.NOT_APPLICABLE', 'Not Applicable'),
#  ('vmp.common.APPLICABLE', 'Applicable'),
#  ('vmp.common.APPLICABILITY_STATUS', 'Applicable Status'),
#  ('vmp.common.PATCH_AVAILABILITY', 'Patch Availability'),
#  ('vmp.common.POLICY_GROUP', 'Policy Group'),
#  ('vmp.common.PUBLISHED_DATE', 'Published Date'),
#  ('vmp.common.PLATFORM', 'Platform'),
#  ('vmp.common.RELEASED_DATE', 'Released Date'),
#  ('vmp.common.SECURITY_CONFIG', 'Security Configurations'),
#  ('vmp.common.UNINSTALL_SW', 'Software Uninstallation'),
#  ('vmp.common.UNINSTALL_SW_report', 'Software Uninstallation Summary'),
#  ('vmp.common.SUPPORTED_DATE', 'Supported Date'),
#  ('vmp.common.THREATS', 'Threats'),
#  ('vmp.common.THREAT_TYPE', 'Threat Type'),
#  ('vmp.common.TYPE', 'Type'),
#  ('vmp.common.TOTAL_RULES', 'Total Rules'),
#  ('vmp.common.TOTAL_POLICIES', 'Total Policies'),
#  ('vmp.common.UNDOSUPPORTED', 'Undo Supported'),
#  ('vmp.common.UPDATED_DATE', 'Updated Date'),
#  ('vmp.common.VULNERABILITIES', 'Vulnerabilities'),
#  ('vmp.common.SOFTWARE_VULNERABILITIES', 'Software Vulnerabilities'),
#  ('vmp.common.SERVER_VULNERABILITIES', 'Server Vulnerabilities'),
#  ('vmp.common.VULNERABILITY', 'Vulnerability'),
#  ('vmp.common.VULNERABILITYID', 'Vulnerability ID'),
#  ('vmp.common.VULNERABILITY_REPORT', 'Vulnerability Report'),
#  ('vmp.common.VULNERABILITY_SUMMARY_REPORT', 'Summary Report'),
#  ('vmp.common.VULNERABILITY_DETAILED_REPORT', 'Detailed Report'),
#  ('vmp.common.WEB_HARDENING', 'Web Server Misconfiguration'),
#  ('vmp.common.WEB_SERVER', 'Web Server'),
#  ('vmp.common.OS_MISCONFIGURATION', 'System Misconfiguration'),
#  ('vmp.common.THREAT_NAME', 'Threat Name'),
#  ('vmp.common.WEB_VULNERABILITY_COUNT', 'Web Vulnerability Count'),
#  ('vmp.common.about', 'About'),
#  ('vmp.common.age', 'Age'),
#  ('vmp.threats.acceptable_risk', 'Acceptable Risk'),
#  ('vmp.threats.false_positive', 'False Positive'),
#  ('vmp.common.declined_by', 'Excluded By'),
#  ('vmp.common.decline_threats', 'Manage Exceptions'),
#  ('vmp.common.revoke_declineThreats_confirm_message',
#   'Do you wish to remove the selected threats from exclusion?'),
#  ('vmp.common.eol', 'End of Life'),
#  ('vmp.common.softwareEOL', 'Software End of Life'),
#  ('vmp.common.false', 'False'),
#  ('vmp.eol.WITHIN_90DAYS', 'Within 90days'),
#  ('vmp.eol.AFTER_90DAYS', 'After 90days'),
#  ('vmp.eol.SOFTWARE', 'Software'),
#  ('vmp.hrs.peer_to_peer_sw', 'Peer to peer Software'),
#  ('vmp.hrs.rds_sw', 'Remote Desktop Sharing Software'),
#  ('vmp.hrs.eol_sw', 'End of Life Software'),
#  ('vmp.common.port_audit', 'Port Audit'),
#  ('vmp.common.port_audit_DESC',
#   'This view lists all the ports that are utilized by applications/services running in your systems.'),
#  ('vmp.common.fix_selected_mc_confirm_message',
#   'Are you sure you want to fix the selected misconfigurations?'),
#  ('vmp.common.fix_selected_vuln_confirm_message',
#   'The latest patches for the selected vulnerabilities will be deployed. Do you want to proceed?'),
#  ('vmp.common.last_deployed_time', 'Last Deployed Time'),
#  ('vmp.common.last_updated_time', 'Last Updated Time'),
#  ('vmp.common.PROTECTION_STATUS', 'Protection Status'),
#  ('vmp.common.ANTIVIRUS', 'Antivirus'),
#  ('vmp.common.no_eol_softwares',
#   'No End-Of-Life software found on the specified criteria'),
#  ('vmp.common.no_fix_available', 'No fix available'),
#  ('vmp.common.fix_available', 'Fix available'),
#  ('vmp.common.no_p2p_softwares',
#   'No Peer-To-Peer software found on the specified criteria'),
#  ('vmp.common.no_rds_softwares',
#   'No Remote Desktop software found on the specified criteria'),
#  ('vmp.common.no_vulnerable_softwares',
#   'No Vulnerable software found on the specified criteria'),
#  ('vmp.common.number_of_days', '{0} days ago'),
#  ('vmp.common.peer_to_peer', 'Peer to peer'),
#  ('vmp.common.rds', 'Remote Desktop Sharing'),
#  ('vmp.common.resolution', 'Resolution'),
#  ('vmp.common.select_one_row', 'Select at least one item'),
#  ('vmp.common.true', 'True'),
#  ('vmp.common.uninstall', 'Uninstall'),
#  ('vmp.common.uninstall_status', 'Uninstallation Status'),
#  ('vmp.common.confirm_fix_threat',
#   'The selected threat will be fixed by deploying a latest patch/ a security configuration. Do you wish to proceed?'),
#  ('vmp.compliance.all_machines_compliant', 'All Machines are Compliant'),
#  ('vmp.compliance.computer_attention_count',
#   '<b class="text--red">{0}</b> computer(s) need attention out of <b>{1}</b> scanned computer(s)'),
#  ('vmp.compliance.rules_failed_count',
#   '<b class="text--red">{0}</b> rules failed out of <b>{1}</b> scanned rules'),
#  ('vmp.compliance.all_passed_rules', 'All rules have been passed'),
#  ('vmp.compliance.deployed_computers', 'Deployed Computers'),
#  ('vmp.compliance.scanned_computers', 'Scanned Computers'),
#  ('vmp.compliance.associated_target_groups', 'Mapped Target Groups'),
#  ('vmp.compliance.associated_policy_groups', 'Mapped Policy Groups'),
#  ('vmp.compliance.mapped_time', 'Mapped Time'),
#  ('vmp.compliance.compliance_percentage', 'Compliance Percentage'),
#  ('vmp.compliance.overall_compliance_percentage',
#   'Overall Compliance Percentage'),
#  ('vmp.compliance.overall_compliance_tooltip',
#   'Percentage of systems that are secure (achieved a compliance percentage of at least 90% each) out of the total systems scanned.'),
#  ('vmp.compliance.scanned_policies', 'Scanned Policies'),
#  ('vmp.compliance.yet_to_scan_policies', 'Yet To Scan Policies'),
#  ('vmp.dashboard.card.antivirus_summary', 'Antivirus Summary'),
#  ('vmp.dashboard.card.network_threats_summary', 'Network threats - Summary'),
#  ('vmp.dashboard.card.NO._OF_THREATS', 'No. of threats'),
#  ('vmp.dashboard.card.apd', 'Automated Patch Deployments'),
#  ('vmp.dashboard.card.computer_by_os', 'Systems by OS'),
#  ('vmp.dashboard.card.critical_threat_vulnerabilties',
#   'Zero-day Vulnerabilities'),
#  ('vmp.dashboard.card.exp_discovery_severity_matrix',
#   'Exploitable Vulnerability Severity by Discovery Date'),
#  ('vmp.dashboard.card.exp_vul_publish_severity_matrix',
#   'Exploitable Vulnerability Severity by Publish Date'),
#  ('vmp.dashboard.card.exp_vulnerability_summary',
#   'Exploitable Vulnerabilities Summary'),
#  ('vmp.dashboard.card.exp_critical_threat_vulns',
#   'Exploitable Zero-day Vulnerabilities'),
#  ('vmp.dashboard.card.failedMisconfiguration', 'Failed Misconfiguration'),
#  ('vmp.dashboard.card.failedUninstallation', 'Failed Uninstallation'),
#  ('vmp.dashboard.card.filter.value.fourteenDays', '14 days'),
#  ('vmp.dashboard.card.filter.value.oneDay', '1 day'),
#  ('vmp.dashboard.card.filter.value.sevenDays', '7 days'),
#  ('vmp.dashboard.card.filter.value.thirtyDays', '30 days'),
#  ('vmp.dashboard.card.filter.value.threeDays', '3 days'),
#  ('vmp.dashboard.card.filter.value.twentyOneDays', '21 days'),
#  ('vmp.dashboard.card.filter.value.twoDays', '2 days'),
#  ('vmp.dashboard.card.fixableVulnerabilities', 'Fixable Vulnerabilities'),
#  ('vmp.dashboard.card.fixablemisconfig', 'Fixable System Misconfigurations'),
#  ('vmp.dashboard.card.globalgpomisconfig', 'Misconfigured in Domain GPO'),
#  ('vmp.dashboard.card.home_page_top', 'Top Counts'),
#  ('vmp.dashboard.card.mc_summary', 'System Misconfiguration Summary'),
#  ('vmp.dashboard.card.misconfig_by_systems_report',
#   'Systems Affected by Misconfigurations'),
#  ('vmp.dashboard.card.misconfig_by_systems', 'Misconfigured Systems'),
#  ('vmp.dashboard.card.newVulnNetwork',
#   'Vulnerabilities Discovered in last {0} day(s)'),
#  ('vmp.dashboard.card.noFixVulnerabilities',
#   'Vulnerabilities With Manual Resolution'),
#  ('vmp.dashboard.card.number_of_deployments', 'Number Of Deployments'),
#  ('vmp.dashboard.card.nwvuln_affsys_report',
#   'Systems Affected by Vulnerabilities'),
#  ('vmp.dashboard.card.nwvuln_affsys', 'Vulnerable Systems'),
#  ('vmp.dashboard.card.pending_update', 'Update Pending'),
#  ('vmp.dashboard.card.resBitLockerCount', 'Bitlocker Disabled'),
#  ('vmp.dashboard.card.BitLockerSystems', 'Bitlocker Disabled Systems'),
#  ('vmp.dashboard.card.resExpireSSLCount', 'SSL Expired'),
#  ('vmp.dashboard.card.ExpiredSSLSystems', 'SSL Expired Servers'),
#  ('vmp.dashboard.card.FirewallSystems', 'Firewall Disabled Systems'),
#  ('vmp.dashboard.card.resScanFailCount', 'Scan Failed Systems'),
#  ('vmp.dashboard.card.risky_sws', 'High Risk Software'),
#  ('vmp.dashboard.card.sysWithoutAgentContact',
#   'Systems without Agent Contact'),
#  ('vmp.dashboard.card.system_health_summary', 'System Health Graph'),
#  ('vmp.dashboard.card.overall_system_status', 'Overall System Status'),
#  ('vmp.dashboard.card.top_vulnerability', 'High Priority Vulnerabilities'),
#  ('vmp.dashboard.card.totalVulnerabilities', 'Total Vulnerabilities'),
#  ('vmp.dashboard.card.totalmisconfig', 'Total System Misconfigurations'),
#  ('vmp.dashboard.card.uptodate', 'Up-to-date'),
#  ('vmp.dashboard.card.vul_discovery_severity_matrix',
#   'Vulnerability Severity by Discovery Date'),
#  ('vmp.dashboard.card.vul_publish_severity_matrix',
#   'Vulnerability Severity by Publish Date'),
#  ('vmp.dashboard.card.vulnerability_matrix', 'Vulnerability Matrix'),
#  ('vmp.dashboard.card.vulnerability_severity_matrix',
#   'Vulnerability Age Matrix'),
#  ('vmp.dashboard.card.vulnerability_summary',
#   'Vulnerability Severity Summary'),
#  ('vmp.dashboard.card.vulnerability_trend', 'Vulnerabilities Over Time'),
#  ('vmp.dashboard.card.high_priority_missing_patches',
#   'High Priority Missing Patches'),
#  ('vmp.dashboard.card.vulnerable_computer_by_os', 'Vulnerable Systems by OS'),
#  ('vmp.dashboard.card.web_hard_summary', 'Web Misconfiguration Summary'),
#  ('vmp.dashboard.card.webserver_summary', 'Web Server Summary'),
#  ('vmp.dashboard.card.web_misconfig_by_systems_report',
#   'Web Servers Affected by Misconfigurations'),
#  ('vmp.dashboard.card.web_misconfig_by_systems', 'Misconfigured Web Servers'),
#  ('vmp.dashboard.cards.windows_defender_disabled',
#   'Windows Defender Disabled'),
#  ('vmp.dashboard.cards.win_defender_disabled_sys',
#   'Windows Defender Disabled Systems'),
#  ('vmp.dashboard.no_data_available', 'Data not yet available'),
#  ('vmp.dashboard.nodata.antivirus_summary',
#   'Track whether your network systems have antivirus enabled and up-to-date with the latest definition files.'),
#  ('vmp.dashboard.nodata.bitlocker_sys',
#   'Track the number of Bitlocker disabled systems in your network.'),
#  ('vmp.dashboard.nodata.critical_threat_vuln',
#   'Get a highlighted view of Zero day vulnerabilities in your network.'),
#  ('vmp.dashboard.nodata.deployment_failed_sys',
#   'Track the number of systems where patches could not be deployed'),
#  ('vmp.dashboard.nodata.discover_severity_matrix',
#   'Get vulnerability age from the day it has been discovered in your network.'),
#  ('vmp.dashboard.nodata.firewall_sys',
#   'Track the number of firewall disabled systems in your network.'),
#  ('vmp.dashboard.nodata.lastcontact_agent_summary',
#   'Check the last time at which agents in your system have contacted the server.'),
#  ('vmp.dashboard.nodata.mc_deployment_failed_sys',
#   'Track the number of systems for which misconfigurations have failed to be fixed.'),
#  ('vmp.dashboard.nodata.patch_approved_matrix',
#   'Analyze and prioritize the missing patches by Approved Time and Severity'),
#  ('vmp.dashboard.nodata.patch_released_matrix',
#   'Analyze and prioritize the missing patches by Released Time and Severity'),
#  ('vmp.dashboard.nodata.patch_status_summary',
#   'Track all the missing and installed patches in your network.'),
#  ('vmp.dashboard.nodata.publish_severity_matrix',
#   'Get vulnerability age from the day it has been published.'),
#  ('vmp.dashboard.nodata.reboot_pending_sys',
#   'Track the number of systems that need a reboot.'),
#  ('vmp.dashboard.nodata.res_mc_summary',
#   'Track the misconfigurations in your resource'),
#  ('vmp.dashboard.nodata.res_patch_status_summary',
#   'Track the installed and missing patches in your resource'),
#  ('vmp.dashboard.nodata.res_threat_summary',
#   'Track the missing patches, vulnerabilities and misconfigurations in in your resource'),
#  ('vmp.dashboard.nodata.res_vulnerability_summary',
#   'Provides the split up of the vulnerabilities in products by severity installed in your resource'),
#  ('vmp.dashboard.nodata.res_webhard_summary',
#   'Track the web server vulnerabilities in your resource'),
#  ('vmp.dashboard.nodata.scan_failed_sys',
#   'Track the number of systems for which the vulnerability scan failed.'),
#  ('vmp.dashboard.nodata.severity_counts',
#   'Get the split up of missing patches in your network by severity.'),
#  ('vmp.dashboard.nodata.ssl_expiry_sys',
#   'Get the number of web servers with expired SSL certificate.'),
#  ('vmp.dashboard.nodata.standard',
#   'This feature is available only in Professional Edition'),
#  ('vmp.dashboard.nodata.system_health_summary',
#   'Provides the split up of the health status of your assets'),
#  ('vmp.dashboard.nodata.systems_by_os',
#   'Obtain the split up of system in your network based on their Operating System.'),
#  ('vmp.dashboard.nodata.vulnerability_summary',
#   'Get the split up of vulnerabilities in your network based on their severity levels.'),
#  ('vmp.dashboard.nodata.vulnerable_trends',
#   'Track and analyse the vulnerability trend in your network. Wait for {0} days for the data to reflect here.'),
#  ('vmp.dashboard.nodata.windows10_systems_by_version',
#   'Obtain the split up of Windows 10 computers in your network based on their versions.'),
#  ('vmp.dashboard.nodata.windows_defender_sys',
#   'Track the number of systems with disabled Windows defender and no third party antivirus.'),
#  ('vmp.dashboard.subtext.no_data_available',
#   'Install Agent and Scan your endpoints to find out the vulnerabilities in network'),
#  ('vmp.deployment.unknown_heading', 'Deployment Status Unknown'),
#  ('vmp.firewall.missing', 'Unable to detect firewall'),
#  ('vmp.firewall.not_up_to_date', 'Firewall Definitions not up to date'),
#  ('vmp.firewall.secure', 'enabled'),
#  ('vmp.firewall.subtext.disabled',
#   'Install a third party firewall to control network traffic'),
#  ('vmp.firewall.subtext.missing',
#   'Install Third Party Firewall to control the traffic that enters and exits this computer'),
#  ('vmp.firewall.subtext.not_up_to_date',
#   'Update the Firewall definitions to secure your network'),
#  ('vmp.firewall.unknown_desc',
#   'Unable to detect firewall presence, as the scan is not yet performed'),
#  ('vmp.firewall.unknown_heading', 'Firewall Status Unknown'),
#  ('vmp.firewall.FIREWALL_NAME', 'Firewall Name'),
#  ('vmp.firewall.DOMAIN_PROFILE_STATUS', 'Domain Profile Status'),
#  ('vmp.firewall.PRIVATE_PROFILE_STATUS', 'Private Profile Status'),
#  ('vmp.firewall.PUBLIC_PROFILE_STATUS', 'Public Profile Status'),
#  ('vmp.firewall.FIREWALL_UPDATE_STATUS', 'Firewall Update Status'),
#  ('vmp.firewall.FIREWALL_LAST_UPDATED_TIME', 'Firewall Last Updated Time'),
#  ('vmp.graph.vuln.no_of_mc', 'Number of misconfigurations'),
#  ('vmp.graph.vuln.no_of_vuln', 'Number of vulnerabilities'),
#  ('vmp.health.unknown_heading', 'Resource Health Status Unknown'),
#  ('vmp.js.common.no_fix_available', 'No Fix Available'),
#  ('vmp.js.dynamicthreats.system.mc.confirmation',
#   'Secure Configurations for the zero-day vulnerabilities will be deployed immediately for the selected resource(s). Do you wish to continue?'),
#  ('vmp.js.dynamicthreats.system.patch.confirmation',
#   'Patch(es) for the zero-day vulnerabilities will be deployed based on the deployment settings which needs to be configured in the upcoming page. Do you wish to continue?'),
#  ('vmp.js.dynamicthreats.system.patchmc.confirmation',
#   'Secure Configurations for the zero-day vulnerabilities will be deployed immediately and the patch(es) will be deployed based on the deployment settings which needs to be configured in the upcoming page for the selected resource(s). Do ypu wish to continue?'),
#  ('vmp.mc.deployment_failed', 'Failed Security Configurations'),
#  ('vmp.mc.deployment_failed_system', 'Security Configurations Failed Systems'),
#  ('vmp.mc.deployment_failed_system_report',
#   'Security Configurations Failed Systems'),
#  ('vmp.mc.fix_manually', 'Fix Manually'),
#  ('vmp.mc.event.fix.failure',
#   'Secure Configurations could not be deployed. Reason\\: {0}'),
#  ('vmp.mc.event.fix.initiated',
#   'Deployment of secure configurations for the misconfigurations {0} has been initiated'),
#  ('vmp.mc.event.fix.success',
#   'Deployment of secure configuration id - {0} is successful for the resource {1}'),
#  ('vmp.mc.event.miscon.declined',
#   'Misconfigurations\\: {0} have been declined successfully'),
#  ('vmp.mc.event.summary.generation_failure',
#   'Misconfiguration Summary Generation could not be performed'),
#  ('vmp.mc.event.summary.generation_success',
#   'Misconfiguration Summary Generation is completed successfully'),
#  ('vmp.mc.event.uninstall_failure',
#   'Uninstallation of software {0} was not successful. Reason\\: {1}'),
#  ('vmp.mc.event.uninstall_success',
#   'Uninstallation of software {0} was successful for the resource {1]'),
#  ('vmp.mc.event.webhard.declined',
#   'Web Server Misconfigurations\\: {0} have been declined successfully'),
#  ('vmp.mc.fixInProgress', 'Deploying Secure Configurations'),
#  ('vmp.mc.fix_misconfig', 'Deploy Secure Configuration'),
#  ('vmp.mc.fix_failed_misconfig', 'Deploy Failed Configuration(s)'),
#  ('vmp.mc.fix_failed_misconfig_tooltip',
#   'Redeploy the failed misconfigurations in the selected systems'),
#  ('vmp.mc.fix_misconfig_tooltip',
#   'Fix all the misconfigurations in the selected systems'),
#  ('vmp.mc.fix.confirmation',
#   'Are you sure you want to fix the security misconfigurations in the selected system(s)?'),
#  ('vmp.mc.fix.select_atleast_one_resource',
#   'Select the computer(s) to deploy the security configurations'),
#  ('vmp.mc.local_admin_user', 'Local Admin User(s)'),
#  ('vmp.mc.local_super_user', 'Local Super User(s)'),
#  ('vmp.mc.manual_resolution', 'View Resolution'),
#  ('vmp.mc.no_potential_impact',
#   'This fix is unlikely to cause any post deployment issues in your network'),
#  ('vmp.mc.port.instances', 'Instances'),
#  ('vmp.mc.port.port_number', 'Port Number'),
#  ('vmp.mc.port.port_type', 'Port Type'),
#  ('vmp.mc.port.port_range', 'Port Range'),
#  ('vmp.mc.port.exe_name', 'Exe Name'),
#  ('vmp.mc.port.system_ports', 'System(0-1023)'),
#  ('vmp.mc.port.registered_ports', 'Registered(1024-49151)'),
#  ('vmp.mc.port.dynamic_ports', 'Dynamic(> 49151)'),
#  ('vmp.mc.port.system_and_registered', 'System and Registered(0-49151)'),
#  ('vmp.common.EXE_PATH', 'Exe Path'),
#  ('vmp.common.EXE_DESC', 'Exe Description'),
#  ('vmp.mc.potential_impact', 'Likely to impact the network'),
#  ('vmp.mc.redeploy', 'Redeploy'),
#  ('vmp.mc.shared_folders', 'Shared Folder(s)'),
#  ('vmp.mc.uninstall_failed', 'Software Uninstallation Failed'),
#  ('vmp.mc.uninstall_failed_report', 'Failed Software Uninstallation'),
#  ('vmp.patch.config.uninstallation_notsupported',
#   'Uninstallation has not been supported for some of the patches that you have selected. Do you want to Continue uninstallation for the Supported Patches?'),
#  ('vmp.patch.config.uninstallation_notsupported_alert',
#   'Patch is not Installed in the network (or) Uninstallation has not been supported for the patches that you have selected. You will not be able to uninstall these patches.'),
#  ('vmp.patch.no_patches_for_vulnerablities',
#   'No patches are available for the selected vulnerabilities'),
#  ('vmp.patch.patch_available', 'Available'),
#  ('vmp.patch.patch_unavailable', 'Not available'),
#  ('vmp.reports.common.VUL_REP_NOT_UP_TO_DATE',
#   'Vulnerability Summary Reports are not up-to-date\\!'),
#  ('vmp.reports.No_scheduler_has_been_created_yet',
#   'No scheduler has been created yet'),
#  ('vmp.reports.common.confidential',
#   "Confidential\\: The following report contains confidential information. Do not distribute, email, fax, or transfer via any electronic media unless it has been approved by the recipient company's security policy. All copies and backups of this document should be saved on protected storage at all times. Do not share any of the information contained within this report with anyone unless they are authorized to view the information. ManageEngine is not to be held liable for any of the consequences that arise from violating any of the above-mentioned instructions."),
#  ('vmp.reports.criticalthreats.affsyscount',
#   'Systems Affected by Zero-day Vulnerabilities'),
#  ('vmp.reports.executiveassetsummary.about.p1',
#   'Get an overview of the assets you manage and details on critical assets that should be prioritized.'),
#  ('vmp.reports.executiveassetsummary.about.p2',
#   'This report delivers a holistic view of the systems you manage and details on critical systems that should be prioritized. You will be able to check the health status, scan status, various deployment status of your network systems to understand your security posture. Also, the high-priority systems section helps you to identify the critical assets that needs immediate attention. Prioritization of systems are the based on the number of vulnerabilities, security misconfigurations, missing patches and high-risk software on each system.'),
#  ('vmp.reports.executiveassetsummary.title', 'Executive Asset Report'),
#  ('vmp.reports.executivepatchsummary.about.p1',
#   'Obtain an overview of the missing patches and deployments that help you track the measures taken to safeguard your enterprise.'),
#  ('vmp.reports.executivepatchsummary.about.p2',
#   'This report delivers an overview of patches that are missing and installed in your network. Also, it provides details on the severity of missing patches. It also delivers a prioritized list of the missing patches in your network based on the severity of the vulnerability it addresses and the number of machines in which it is missing. With this report, you can track the deployment status of patches, so that you can track the measures taken to safeguard your enterprise.'),
#  ('vmp.reports.executivepatchsummary.title', 'Executive Patch Summary'),
#  ('vmp.reports.executivepriorityreport.title', 'High Priority Report'),
#  ('vmp.reports.executivevulnerabilitysummary.about.p1',
#   'Get a holistic view of vulnerabilities, system and server misconfigurations in your network.'),
#  ('vmp.reports.executivevulnerabilitysummary.about.p2',
#   'This report delivers a holistic view of vulnerabilities, system and server misconfigurations in your network. This information helps you to assess your security posture, find your weak spots and rectify them. You can get the split up of vulnerabilities and misconfigurations based on various risk assessment factors such as severity, exploitability, number of days it has been present in your network and the number of systems affected. Also, this report delivers a prioritized list of vulnerabilities, and misconfigurations which will help you track down and rectify extremely critical threats.'),
#  ('vmp.reports.executivevulnerabilitysummary.title',
#   'Executive Vulnerability Report'),
#  ('vmp.reports.exploitable_vulnerabilitysummary',
#   'Summary of Exploits Available Vulnerabilities'),
#  ('vmp.reports.misconfigurationoverview.title',
#   'Overview of Security Misconfigurations'),
#  ('vmp.reports.misconfigurations.end_of_life_sw_DESC',
#   'This view displays all the software in the network whose expiry details are available.'),
#  ('vmp.reports.mc.misconfigured_systems',
#   'Detailed information about the misconfigured systems in your network.'),
#  ('vmp.reports.misconfigurations.misconfigured_systems_DESC',
#   'Detailed information about the misconfigured systems.'),
#  ('vmp.reports.misconfigurations.open_ports_DESC',
#   'This view displays all the open ports in the network.'),
#  ('vmp.reports.misconfigurations.os_misconfigurations',
#   'System Misconfigurations'),
#  ('vmp.reports.misconfigurations.os_misconfigurations_DESC',
#   'This view displays all the OS misconfiguration in the network.'),
#  ('vmp.reports.misconfigurations.peer_to_peer_DESC',
#   'This view displays all the peer to peer software in the network.'),
#  ('vmp.reports.misconfigurations.rds_DESC',
#   'This view displays all the remote desktop sharing software in the network.'),
#  ('vmp.reports.misconfigurations.res_end_of_life_sw_DESC',
#   'This view displays all the software in the resource that have expired or are nearing end of life.'),
#  ('vmp.reports.misconfigurations.res_open_ports_DESC',
#   'This view displays all the open ports in a particular resource.'),
#  ('vmp.reports.misconfigurations.res_os_misconfigurations_DESC',
#   'This view displays all the OS misconfiguration in a particular resource.'),
#  ('vmp.reports.misconfigurations.res_peer_to_peer_DESC',
#   'This view displays all the peer to peer software in a particular resource.'),
#  ('vmp.reports.misconfigurations.res_rds_DESC',
#   'This view displays all the remote desktop sharing software in a particular resource.'),
#  ('vmp.reports.misconfigurations.res_webserver_hardening_DESC',
#   'This view displays all the configuration settings in web servers that potentially weaken the resource.'),
#  ('vmp.reports.mc.web_misconfigured_sys_DESC',
#   'Detailed information about the  systems  with web server misconfigurations in your network.'),
#  ('vmp.reports.misconfigurations.webserver_hardening_DESC',
#   'This view displays all the configuration settings in web servers that potentially weaken the network.'),
#  ('vmp.reports.mc.software_uninstallation_dep_DESC',
#   'This view displays the status of high-risk software for which uninstallation has been initiated.'),
#  ('vmp.reports.mc.security_config_dep_DESC',
#   'This view displays the status of system misconfigurations for which appropriate security configurations have been deployed.'),
#  ('vmp.reports.networkassetoverview.title', 'Network System Overview'),
#  ('vmp.reports.networkpatchoverview.title', 'Network Patch Overview'),
#  ('vmp.reports.networkvulnoverview.title',
#   'Overview of Network Vulnerabilities'),
#  ('vmp.reports.patchnetworkstatus.title', 'Network Patch Status'),
#  ('vmp.reports.prioritizeassets.title', 'High priority systems'),
#  ('vmp.reports.prioritizemisconfig.title', 'High Priority Misconfigurations'),
#  ('vmp.reports.prioritizepatches.title', 'High Priority Patches'),
#  ('vmp.reports.prioritizevulnerability.title',
#   'High Priority Vulnerabilities'),
#  ('vmp.reports.priorityreport.about.p1',
#   'Get a prioritized list of the systems, vulnerabilities, misconfigurations and other flaws that are more likely to be exploited and needs immediate attention.'),
#  ('vmp.reports.priorityreport.about.p2',
#   'This report delivers a prioritized list of the systems, vulnerabilities, misconfigurations and other flaws that are more likely to be exploited and needs immediate attention. Prioritization of systems are based on the number of vulnerabilities, security misconfigurations and high risk software present in them. Prioritization of vulnerabilities, security misconfigurations and high risk software are based on their severity and exploitability. Prioritization of patches are based on the severity of the vulnerabilities they address. It is advisable to eliminate all the security threats displayed in this report to minimize your attack surface and improve your network security.'),
#  ('vmp.reports.reportupdatemsg.Failed_to_update_vul_report',
#   'Failed to update vulnerability report...'),
#  ('vmp.reports.reportupdatemsg.vul_report_updation_in_progress',
#   'Vulnerability report update in progress...'),
#  ('vmp.reports.resource.applicationvulnerabilities',
#   'Application Vulnerabilities'),
#  ('vmp.reports.resource.ransomware', 'Ransomware'),
#  ('vmp.reports.resourcehealthoverview.about.p1',
#   'Provides an overview of the patches and vulnerabilities in a resource.'),
#  ('vmp.reports.resourcehealthoverview.about.p2',
#   'This report helps you ease the tension by providing you the list of patches, systems, vulnerabilities, misconfigurations and other threats that you have to act on immediately. The patch status summary provided you with the higher level view of the missing and installed patches in your network. Prioritize the missing patches using the severity split up graph. The next set of sections helps you understand about the health of the resource.'),
#  ('vmp.reports.resourcehealthoverview.title', 'Resource Health Overview'),
#  ('vmp.reports.resourcepatches.title', 'Resource-level Patches'),
#  ('vmp.reports.resourcesecurityconfig.title',
#   'Resource-level Security Configurations'),
#  ('vmp.reports.resourcevulnerabilities.title',
#   'Resource-level Vulnerabilities'),
#  ('vmp.reports.system.topten.downloadfailedpatches',
#   'Top Download Failed Patches'),
#  ('vmp.reports.system.topten.patches', 'Top Missing Patches'),
#  ('vmp.reports.system.topten.systemswithdepfailed',
#   'Systems with highest patch deployment failure'),
#  ('vmp.reports.system.topten.unapprovedmissingpatches',
#   'Top Unapproved Missing Patches'),
#  ('vmp.reports.system.topten.webserveraffectedsys',
#   'Top Misconfigured Web Servers'),
#  ('vmp.reports.systems.av_misconfigured',
#   'Systems with Misconfigured Antivirus Software'),
#  ('vmp.reports.systems.av_misconfigured_DESC',
#   'Detailed information about the systems with antivirus misconfigurations.'),
#  ('vmp.reports.systems.criticalthreats_DESC',
#   'Detailed information about the systems affected by zero-day vulnerabilities.'),
#  ('vmp.reports.systems.fixed_misconfig_DESC',
#   'Detailed information about the systems with resolved misconfigurations.'),
#  ('vmp.reports.systems.mc_dep_failed_DESC',
#   'Detailed information about the systems with failed security configuration deployments.'),
#  ('vmp.reports.systems.noagentcontact', 'Systems with No Agent Contact'),
#  ('vmp.reports.systems.noagentcontact_DESC',
#   'Detailed information about the systems with no agent contact for a particular time period.'),
#  ('vmp.reports.systems.patch_dep_failed_DESC',
#   'Detailed information about the systems with failed patch deployments.'),
#  ('vmp.reports.systems.reboot_reqd_DESC',
#   'Detailed information about the systems requiring reboot.'),
#  ('vmp.reports.systems.riskysoftwares', 'Systems affected by Risky Software'),
#  ('vmp.reports.systems.riskysw', 'By High Risk Software'),
#  ('vmp.reports.systems.riskysw_report', 'Systems with High Risk Software'),
#  ('vmp.reports.systems.web_misconfig_by_systems',
#   'By Web Server Misconfigurations'),
#  ('vmp.reports.systems.misconfig_by_systems', 'By Misconfigurations'),
#  ('vmp.reports.systems.riskysw_DESC',
#   'Detailed information about the systems with high-risk software.'),
#  ('vmp.reports.systems.antivirus', 'System Antivirus Report'),
#  ('vmp.reports.systems.antivirus_DESC',
#   'This view displays a list of antivirus software along with its details across all the Windows and Linux systems.'),
#  ('vmp.reports.systems.firewall', 'System Firewall Report'),
#  ('vmp.reports.systems.windows_firewall', 'Windows Defender Firewall Report'),
#  ('vmp.reports.systems.windows_firewall_DESC',
#   'This view displays a list of Windows Defender firewalls along with their details across all the Windows systems.'),
#  ('vmp.reports.systems.tp_firewall', 'Third-party Firewall Report'),
#  ('vmp.reports.systems.tp_firewall_DESC',
#   'This view displays a list of third-party firewalls along with their details across all the Windows and Linux systems.'),
#  ('vmp.reports.status.updated', 'Updated'),
#  ('vmp.reports.status.yet_to_be_updated', 'Yet to be updated'),
#  ('vmp.reports.topten.affectedproducts', 'Top Affected Software'),
#  ('vmp.reports.topten.avdisabledsystems', 'Systems with No Antivirus'),
#  ('vmp.reports.topten.firewalldisabledsystems', 'Firewall disabled systems'),
#  ('vmp.reports.topten.highlyvulnerablesystems', 'Top Vulnerable Systems'),
#  ('vmp.reports.topten.misconfigurations', 'Top System Misconfigurations'),
#  ('vmp.reports.topten.misconfiguredsystems', 'Top Misconfigured Systems'),
#  ('vmp.reports.topten.riskysoftwares', 'Top High Risk Software'),
#  ('vmp.reports.topten.vulaffectedsys', 'Top Affected Systems'),
#  ('vmp.reports.topten.vulnerabilities', 'Top Software Vulnerabilities'),
#  ('vmp.reports.vulnerability.critical_vulnerability',
#   'Zero Day Vulnerability Report'),
#  ('vmp.reports.vulnerability.critical_vuln_DESC',
#   'This view displays all the critical and zero-day vulnerabilities in the network like Meltdown, Spectre, etc.'),
#  ('vmp.reports.vulnerability.failed_mc_DESC',
#   'This view displays all the misconfiguration with failed deployment in the network.'),
#  ('vmp.reports.vulnerability.fixed_mc_DESC',
#   'This view displays all the misconfiguration that were fixed in the network.'),
#  ('vmp.reports.vulnerability.network_nofix_vulnerability_DESC',
#   'This view displays all the vulnerabilities without fixes present in the network.'),
#  ('vmp.reports.vulnerability.network_vulnerability',
#   'Network Vulnerability Report'),
#  ('vmp.reports.vul.network_vulnerability_no_fix',
#   'Network Vulnerability No Fixes Report'),
#  ('vmp.reports.vulnerability.network_vulnerability_DESC',
#   'This view displays all the vulnerabilities present in the network.'),
#  ('vmp.reports.vulnerability.res_critical_vuln_DESC',
#   'This view displays all the critical and zero-day vulnerabilities like Meltdown, Spectre, etc. in a particular resource.'),
#  ('vmp.reports.vulnerability.res_nofix_vulnerability_DESC',
#   'This view displays all the vulnerabilities without fixes present in a particular resource.'),
#  ('vmp.reports.vulnerability.res_vulnerability', 'Resource Vulnerabilities'),
#  ('vmp.reports.vulnerability.res_vulnerability_DESC',
#   'This view displays all the vulnerabilities present in a particular resource.'),
#  ('vmp.reports.vul.system_vulnerability_DESC',
#   'Detailed information about the systems with vulnerabilities in your network.'),
#  ('vmp.reports.vulnerability.tech_aff_prod_DESC',
#   'This view displays all the vulnerability affected products in the network.'),
#  ('vmp.reports.vulnerability.tech_prod_vulnerability',
#   'Product Vulnerabilities'),
#  ('vmp.reports.vulnerability.tech_prod_vulnerability_DESC',
#   'This view displays all the vulnerabilities for a particular product in the network.'),
#  ('vmp.reports.vulnerability.tech_web_vulnerability',
#   'Web Server Vulnerabilities'),
#  ('vmp.reports.vulnerability.tech_db_vulnerability',
#   'Database Server Vulnerabilities'),
#  ('vmp.reports.vulnerability.content_management',
#   'Content Management Systems'),
#  ('vmp.reports.vulnerability.tech_web_vulnerability_DESC',
#   'This view displays all the vulnerabilities for a particular web server in the network.'),
#  ('vmp.reports.vulnerabilitytrend_onemonth',
#   'Vulnerability Trend for the Last 90 days'),
#  ('vmp.reports.generationtype.scheduled', 'Scheduled'),
#  ('vmp.reports.vulnerability.software_vulnerability',
#   'Software Vulnerability Report'),
#  ('vmp.reports.vulnerability.software_vuln_no_fixes',
#   'Software Vulnerability No Fixes Report'),
#  ('vmp.reports.vulnerability.software_vuln_report',
#   'Software Vulnerabilities'),
#  ('vmp.reports.generatedreports.generatedtype', 'Generation type'),
#  ('vmp.reports.generatedreports.generatedby', 'Generated By'),
#  ('vmp.reports.generatedreports.download', 'Download'),
#  ('vmp.reports.generatedreports.delete', 'Delete'),
#  ('vmp.riskysw.uninstall.initiated',
#   'Uninstallation of software {0} has been initiated'),
#  ('vmp.som.agent.days_without_contact', 'Days without contact'),
#  ('vmp.summary.generation_failure',
#   'Vulnerability Summary Generation could not be performed'),
#  ('vmp.summary.generation_success',
#   'Vulnerability Summary Generation is completed successfully'),
#  ('vmp.vuldetailsaction.Preparing_data_for_Vuln_Scan',
#   'Preparing and Syncing vulnerability scan data'),
#  ('vmp.vuldetailsaction.Prep_data_for_Lin_Vuln_Scan',
#   'Preparing and Syncing Linux vulnerability scan data'),
#  ('vmp.vuln.THREAT_CATEGORY', 'Threat Category'),
#  ('vmp.vuln.affected_systems', 'Affected Systems'),
#  ('vmp.vuln.card.exploitable', 'Exploit(s) available'),
#  ('vmp.vuln.critical_vuln', 'Critical Vulnerabilities'),
#  ('vmp.vuln.cvss2_overall_score', 'CVSS 2.0 Score'),
#  ('vmp.vuln.cvss2_vector', 'CVSS 2.0 Vector'),
#  ('vmp.vuln.cvss3_overall_score', 'CVSS 3.0 Score'),
#  ('vmp.vuln.cvss3_vector', 'CVSS 3.0 Vector'),
#  ('vmp.vuln.declined',
#   'Vulnerabilities\\: {0} have been declined successfully'),
#  ('vmp.vuln.deployed_systems', 'Deployed Systems'),
#  ('vmp.vuln.expired_SW', 'Expired Software'),
#  ('vmp.vuln.near_eol_SW', 'Software Nearing EOL'),
#  ('vmp.vuln.greater_eol_SW', 'Software with time to expiry'),
#  ('vmp.vuln.near_eol_SW_toolTip',
#   'This column shows the number of software that are set to expire within a period of {0} days.'),
#  ('vmp.vuln.greater_eol_SW_toolTip',
#   'This column shows the number of software that will only expire after {0} or more days.'),
#  ('vmp.vuln.not_exploitable', 'Exploit(s) unavailable'),
#  ('vmp.vuln.software_expiry_today', 'Expiring Today'),
#  ('vmp.vuln.software_expire_left', '{0} days left to expire'),
#  ('vmp.vuln.zero_day_deploy_fixes', 'Deploy Fixes'),
#  ('vmp.vuln.zero_day_fix_tooltip',
#   'Deploy patches/secure configurations to resolve these Zero-day Vulnerabilities'),
#  ('vmp.vulnerability.matrix.greater_than_ninety', '>90 days'),
#  ('vmp.vulnerability.matrix.less_than_thirty', '<30 days'),
#  ('vmp.vulnerability.matrix.sixty_to_ninety', '60-90 days'),
#  ('vmp.vulnerability.matrix.thirty_to_sixty', '30-60 days'),
#  ('vmp.windowsfirewall.enabled', 'Windows Firewall Enabled'),
#  ('vmp.common.VULNERABILITY_NAME', 'Vulnerability Name'),
#  ('vmp.common.WEBSERVER_NAME', 'Web Server Name'),
#  ('vmp.common.DBSERVER_NAME', 'DB Server Name'),
#  ('vmp.common.MISCONFIG_NAME', 'Misconfiguration Name'),
#  ('vmp.common.Remediation_availability', 'Remediation availability'),
#  ('vmp.common.Post_Deployment_Issue', 'Post Deployment Issue'),
#  ('vmp.common.Misconfigured_in_GPO', 'Misconfigured in GPO'),
#  ('vmp.vuln.card.not_exploitable', 'Exploit(s) Unavailable'),
#  ('vmp.cve.cve_type', 'CVE type'),
#  ('vmp.cve.exploits_count', 'Exploits Count'),
#  ('vmp.cve.cve_details_report', 'Detected CVE Summary'),
#  ('vmp.cve.cve_details', 'Detected CVEs'),
#  ('vmp.cve.cve_id', 'CVE ID'),
#  ('dc.common.FIX_CVE', 'Fix CVE'),
#  ('vmp.table.description.cve_details',
#   'This table enumerates the CVEs detected in Windows and Linux operating systems as well as third-party applications.'),
#  ('vmp.common.No_CVE_Details', 'No CVE details'),
#  ('vmp.common.msg.CVE_Details_title', 'Introducing Detected CVEs view!'),
#  ('vmp.common.msg.CVE_Details_content', 'Now you can utilize'),
#  ('vmp.cve.CWE_ID', 'CWE ID'),
#  ('vmp.common.msg.VMP_LINUX_TITLE',
#   'Introducing threat and vulnerability management for Linux!'),
#  ('vmp.common.msg.VMP_LINUX_DESC',
#   'All the capabilities of Vulnerability Manager Plus are now supported for Linux endpoints.'),
#  ('vmp.common.msg.VMP_LINUX_content',
#   'of all the Linux distros and third-party applications supported for Linux platform.'),
#  ('vmp.common.msg.VMP_LINUX_MSG_URL', 'View the complete list'),
#  ('vmp.reports.vulnerability.detedtedCVE_DESC',
#   'This table provides detailed information on all the CVEs that affect Microsoft OS and applications as well as third-party applications for Windows.'),
#  ('vmp.cve.no_patch', 'Patches are not available for selected CVEs.'),
#  ('vmp.admin.uac.default_networkdevice_manager',
#   'Has access only to Network Devices module'),
#  ('vmp.common.msg.nwdevice_msg_title',
# ...
#  ('vmp.quarantineCompliance.file_folder_path', 'File/Folder Path'),
#  ('vmp.quarantineCompliance.file_path', 'Enter File Path'),
#  ('vmp.quarantineCompliance.file_version', 'Enter File Version'),
#  ('vmp.quarantineCompliance.perform_actions', 'Perform the following actions'),
#  ('vmp.quarantineCompliance.audit', 'Audit Only'),
#  ('vmp.quarantineCompliance.quarantine', 'Quarantine'),
#  ('vmp.quarantineCompliance.action', '--Action--'),
#  ('vmp.quarantineCompliance.action_note',
#   'Note: We recommend performing an audit before quarantining the systems to get a list of non-compliant systems.'),
#  ('vmp.quarantineCompliance.actions_network', 'Block All Network Access'),
#  ('vmp.quarantineCompliance.actions_domain',
#   'Allow access only to custom IP/VPN/Domains'),
#  ('vmp.quarantineCompliance.actions_internet', 'Block only Intranet in range'),
#  ('vmp.quarantineCompliance.actions_custom', 'Block Custom IP & Domain'),
#  ('vmp.quarantineCompliance.actions_intranet', 'Enter the Intranet Range'),
#  ('vmp.quarantineCompliance.actions_custom_domain',
#   'Enter Custom Domain and IP'),
#  ('vmp.quarantineCompliance.certain_domain', 'Allow Access to Certain Domain'),
#  ('vmp.quarantineCompliance.domain_name', 'Enter Domain Name'),
#  ('vmp.quarantineCompliance.custom_domain', 'Allow Access to Custom IP'),
#  ('vmp.quarantineCompliance.gateway', 'Allow Access to VPN Gateway'),
#  ('vmp.quarantineCompliance.certain_ip', 'Allow Access To Certain Ip'),
#  ('vmp.quarantineCompliance.warning_message', 'Alert Users'),
#  ('vmp.quarantineCompliance.configure_notification',
#   'Configure Notifications'),
#  ('vmp.quarantineCompliance.notification_description',
#   'Enabling this option, will automaticallly send notifications via email based on the specified frequency.'),
#  ('vmp.quarantineCompliance.warning_description',
#   'Enabling this option, automatically sends alerts to the user based on the input.'),
#  ('vmp.quarantineCompliance.create_policy', 'Create Compliance Policies'),
#  ('vmp.quarantineCompliance.policy_description',
#   'Streamline compliance across your network by ensuring all the systems adhere to the defined set of rules.'),
#  ('vmp.quarantineCompliance.audit_machines', 'Audit the Systems'),
#  ('vmp.quarantineCompliance.audit_description',
#   'Audit systems for compliance. Isolate non-compliant systems from the network. Notify users about adhering to compliance.'),
#  ('vmp.quarantineCompliance.isolate_machines',
#   'Isolate Non-Compliant Systems'),
#  ('vmp.quarantineCompliance.isolate_description',
#   'Restrict non-compliant systems access to the network, Intranet, or custom IP & domain.'),
#  ('vmp.common.msg.quarantine_title',
#   'Introducing System Quarantine Policy to maintain system-level compliance'),
#  ('vmp.common.msg.quarantine_compliance_content',
#   'Ensure systems in your network are secure by adhering to enterprise compliance standards'),
#  ('vmp.quarantine_compliance_link',
#   'Begin your Quarantine Compliance journey now!'),
#  ('vmp.quarantineCompliance.rules', 'Quarantine Rules'),
#  ('vmp.quarantineCompliance.systems', 'Quarantined Systems'),
#  ('vmp.quarantineCompliance.to_be_quarantine', 'To Be Quarantined'),
#  ('vmp.quarantineCompliance.excluded', 'Excluded Systems'),
#  ('vmp.quarantineCompliance.scan_time', 'Last Scanned Time'),
#  ('vmp.quarantineCompliance.isolate_time', 'Isolated Time'),
#  ('vmp.quarantineCompliance.total_machines', 'Total Systems'),
#  ('vmp.quarantineCompliance.temporary_list', 'Temporary Exclusion List'),
#  ('vmp.quarantineCompliance.remove_machines',
#   'The selected systems will be excluded from quarantine for:'),
#  ('vmp.quarantineCompliance.remove_isolation', 'Remove System From Isolation'),
#  ('vmp.quarantineCompliance.exclude', 'Extend Exclusion'),
#  ('vmp.quarantineCompliance.remove_exclusion', 'Remove From Exclusion List'),
#  ('vmp.quarantineCompliance.remove_exclusion_action', 'Remove Exclusion'),
#  ('vmp.quarantineCompliance.remove_exclusion_confirm',
#   'If the systems removed from the Exclusion List do not adhere to the Quarantine Rules, the systems will be considered non-compliant and the Quarantine Actions associated with the policy will be applicable to these systems. Are you sure you want to continue?'),
#  ('vmp.quarantineCompliance.quarantine_confirmation', 'Yes, Remove'),
#  ('vmp.quarantineCompliance.extend_exclusion', 'Extend Exclusion'),
#  ('vmp.quarantineCompliance.extend_exclusion_note',
#   'Note: Systems remain quarantined for an extended period'),
#  ('vmp.quarantineCompliance.compliant', 'Compliance Status'),
#  ('vmp.quarantineCompliance.remove_quarantine',
#   'Selected system(s) have been removed from Quarantine successfully'),
#  ('vmp.quarantineCompliance.not_quarantine',
#   'Selected system(s) have been extended from grace period successfully'),
#  ('vmp.quarantineCompliance.remove_from_exclusion',
#   'Selected system(s) have been removed from exclusion successfully'),
#  ('vmp.quarantineCompliance.extend_from_exclusion',
#   'Selected system(s) have been extended from exclusion successfully'),
#  ('dc.alerts.quarantine_compliance_report_sub',
#   'Quarantine Compliance Report'),
#  ('vmp.quarantineCompliance.again_quarantine',
#   'Note: Systems will be quarantined again if they are found not compliant of the rules.'),
#  ('vmp.compliance.excluded_on', 'Excluded On'),
#  ('vmp.compliance.excluded_till', 'Excluded UpTo'),
#  ('vmp.compliance.missing_service', 'Missing Quarantine Rule'),
#  ('vmp.compliance.will_be_isolation', 'To Be Quarantined On'),
#  ('dc.common.created_time', 'Created Time'),
#  ('dc.patch.scan_failed_rules', 'Rules failed to scan'),
#  ('dc.patch.scanned_all_rules', 'All rules have been scanned'),
#  ('dc.patch.SAVE_AND_SCAN', 'Save and scan'),
#  ('dc.compliance.create_audit', 'Create Audit'),
#  ('dc.compliance.create_audit_scan', 'Create Audit and scan now'),
#  ('dc.compliance.create_grp', 'Create Group'),
#  ('dc.compliance.map_and_audit_target', 'Map and Audit Targets'),
#  ('dc.compliance.compliance_audit', 'Compliance Audit'),
#  ('dc.compliance.status.below_percent', 'Below {0}%'),
#  ('dc.compliance.status.above_percent', 'Above {0}%'),
#  ('dc.compliance.scan_failed', 'Failed to initiate scan'),
#  ('dc.compliance.scanning_started',
#   'Scan has been initiated for the target group'),
#  ('dc.compliance.scan_all_confirm',
#   'Scanning is performed automatically as per the compliance scan schedule. Do you still want to initiate this scan?'),
#  ('dc.compliance.scan_all_cooldown_alert',
#   'All managed system(s) are currently being scanned. Retry scanning system(s) after {0} minute(s).'),
#  ('dc.compliance.disabled_benchmark_tooltip',
#   'Compliance audit only runs on target systems whose OS matches the compliance policy type.'),
#  ('dc.compliance.rules_passed_percentage_tooltip',
#   'Percentage of rules passed out of total scanned rules (excluding unscored rules).'),
#  ('dc.compliance.create_target_grp', 'Create Target group'),
#  ('dc.compliance.cant_delete_policy_grp',
#   'The policy group can not be deleted since it is mapped to the following target group(s):{0}'),
#  ('dc.patch.moved_to_policy_groups',
#   'Policy {0} has been added to policy groups'),
#  ('dc.compliance.failed_to_add_to_policy_groups',
#   'Failed to add policy {0} to policy groups'),
#  ('dc.compliance.create_policy_grp_desc',
#   'Recommendation: Group policies based on OS in order to effectively map them to targets belonging to the same OS'),
#  ('dc.compliance.policy_grp_desc',
#   'Create Policy Groups to easily map policies to target systems for compliance audit.'),
#  ('dc.compliance.specify_target_desc',
#   'Note: Compliance audit only runs on target systems whose OS matches the policy type.'),
#  ('dc.compliance.associate_policy_desc',
#   'Click on a target group to view its compliance status.'),
#  ('dc.compliance.COMPLIANT', 'Compliant'),
#  ('dc.compliance.delete_confirm_message', 'Are you sure you want to delete?'),
#  ('dc.compliance.computer_need_attention_tooltip',
#   'Computers that are below 90% compliance'),
#  ('dc.msg.cis_db_not_uptodate_title', 'Compliance data is not Up-to-date'),
#  ('dc.msg.cis_db_not_uptodate_content',
#   'The compliance data is not up-to-date.'),
#  ('dc.msg.cis_db_not_uptodate_contact_admin_content',
#   'Contact your Administrator to make it up to date.'),
#  ('dc.msg.cis_db_not_uptodate_link_content', '<a>Update Now</a>'),
#  ('dc.vul.common.CIS_DB_UPDATE_FAILED',
#   'Compliance data sync failed. <a href=\\"https://www.manageengine.com/vulnerability-management/knowledge-base/compliance-data-sync-failure.html" class="bluetxt" target=\\"_blank\\">Read KB</a>'),
#  ('dc.compliance.scheduler.specified_days', 'Specified days'),
#  ('dc.compliance.scheduler.alternate_days', 'Alternate days'),
#  ('dc.compliance.scheduler.preferred_week', 'Preferred week(s) of the month'),
#  ('dc.compliance.scheduler.preferred_day', 'Preferred day of the month'),
#  ('dc.patch.compliance.server_timezone',
#   'Date and time is based on server timezone'),
#  ('dc.compliance.compliance_status', 'Compliance Status'),
#  ('dc.compliance.rules_passed', 'Rules Passed'),
#  ('dc.patch.customgrp.alreadyAssosiated',
#   'The custom group has already associated. Do you want to modify?'),
#  ('vmp.common.msg.cis_compliance_title', 'Introducing CIS compliance!'),
#  ('vmp.common.msg.cis_linux_compliance_title',
#   'Introducing CIS compliance for Linux machines'),
#  ('vmp.common.msg.cis_linux_compliance_content',
#   'Ensure your Linux machines achieve compliance standards with out-of-the box support for CIS benchmarks'),
#  ('vmp.common.msg.cis_compliance_content',
#   'Now you can audit your systems for compliance against CIS benchmarks, identify violations and receive detailed remediation insights.'),
#  ('vmp.cis.compliance.link', 'Begin your compliance journey now!'),
#  ('vmp.common.msg.cis_compliance_sync_content',
#   'New files and changes related to compliance policies from the central vulnerability database synchronize regularly with the central server at 1 am everyday. Note: This data will not be updated during the usual vulnerability database sync.'),
#  ('vmp.common.msg.cis_compliance_sync_title', 'Compliance data sync schedule'),
#  ('vmp.updatedb.Compliance_info_update_success',
#   'Compliance Database updated successfully.'),
#  ('vmp.updatedb.Compliance_DB_IN_SYNC', 'Compliance database is up-to-date.'),
#  ('vmp.updatedb.Failed_to_Update_the_Compliance_1',
#   'Failed to Update the Compliance DataBase due to'),
#  ('vmp.msg.cis_db_sync_failed_title', 'Compliance data sync failed'),
#  ('vmp.msg.cis_db_sync_failed_content', 'Compliance data sync failed.'),
#  ('vmp.common.policy_group_created', 'Policy group {0} has been created'),
#  ('vmp.common.policy_group_modified', 'Policy group {0} has been modified'),
#  ('vmp.common.policy_group_deleted', 'Policy group {0} has been deleted'),
#  ('vmp.common.target_group_created', 'Target group {0} has been created'),
#  ('vmp.common.target_group_modified', 'Target group {0} has been modified'),
#  ('vmp.compliance.customgroup_resource_view',
#   'In a custom group, the associated policies are only applied to the computers based on their OS platform.'),
#  ('vmp.compliance.Next_Scan_Scheduled_at', 'Next Scan Scheduled at'),
#  ('vmp.compliance.Scan_Frequency', 'Scan Frequency'),
#  ('vmp.compliance.cg_resource_view_suspended',
#   'The scan results could not be updated since the audit was suspended during the scheduled scan. The data will be updated once the systems are scanned on the next schedule.'),
#  ('vmp.compliance.cg_resource_view_scan_update',
#   'The <b>Compliance Percentage</b> will be updated after the scheduled compliance scan time. If the system is offline during the scheduled scan, the percentage will be updated post scanning, at the next refresh cycle.'),
#  ('vmp.common.target_group_deleted', 'Target group {0} has been deleted'),
#  ('vmp.compliance.sync_initiated', 'Compliance data sync has been initiated'),
#  ('vmp.compliance.sync_in_progress', 'Compliance data sync is in progress'),
#  ('vmp.compliance.sync_failed', 'Failed to initiate compliance data sync'),
#  ('vmp.compliance.mapped_by', 'Mapped by'),
#  ('vmp.compliance.scan_schedule',
#   'Schedule the scan to be initiated in at least 3 hours from now.'),
#  ('vmp.compliance.scan_started',
#   'Scan has been initiated for the target group {0}'),
#  ('vmp.table.description.system_misconfig_sub_desc',
#   'View the complete list of all the misconfiguration supported.'),
#  ('dc.vmp.patchsummary.Threat_and_Patch_Summary', 'Threat and Patch Summary'),
#  ('desktopcentral.vmp.patchSummary.page_Description',
#   'View the details of the missing patches, installed patches, software vulnerabilities, misconfigurations, vulnerable systems etc., of all customers.'),
#  ('vmp.threats.no_fix_mc',
#   "Selected item can't be fixed from the console. For more details, click on a misconfiguration to view its description."),
#  ('vmp.threats.misconfig_systems_alert',
#   'This action fixes all the misconfigurations from the selected system(s). some of the misconfigurations may have post-deployment issues.'),
#  ('vmp.threats.misconfig_systems_note',
#   'Note: Click on a misconfiguration in the security misconfiguration view to view its post-deployment issue.Do you wish to proceed?'),
#  ('vmp.misconfig.confirm_fix_mc_with_impact',
#   'Fixing the selected item may have the following post-deployment issue: {impact}. Do you wish to proceed?'),
#  ('vmp.misconfig.impacts_available_alert',
#   '{impactCount} of the selected item(s) have post-deployment issues.'),
#  ('vmp.misconfig.fixes_available_alert',
#   "{noFixCount} of the selected item(s) can't be fixed from the console."),
#  ('vmp.misconfig.mc_impact_alert',
#   'Note: Click on the individual misconfiguration to view respective details.Do you wish to proceed?'),
#  ('vmp.compliance.policy_grp_restrict_action_alert',
#   'Policy groups created by another user cannot be modified or deleted.'),
#  ('vmp.compliance.target_grp_restrict_action_alert',
#   'Target groups created by another user cannot be modified or deleted.'),
#  ('vmp.compliance.result_data_absolute_msg',
#   'If a policy group mapped to the targets is later modified to add/remove policies, those changes will not be reflected until the subsequent scan.'),
#  ('vmp.compliance.compliance_schedule_modified',
#   '{0} - Compliance Scheduled report has been modified'),
#  ('dc.alerts.compliance_report_sub', 'Compliance Report'),
#  ('vmp.quicklink.compliance_policies_terminology',
#   'Understanding the terminologies used in the compliance policies'),
#  ('vmp.quicklink.compliance_audit_results',
#   'Understanding compliance audit results'),
#  ('vmp.quicklink.compliance_statuses', 'Understanding compliance statuses'),
#  ('vmp.howto.grouping_policies_for_audit',
#   'How to group policies for compliance audit?'),
#  ('vmp.howto.grouping_builtin_templates',
#   'How to use built-in policy group templates?'),
#  ('vmp.howto.map_and_audit_to_target_group',
#   'How to map policies to target group and schedule audits?'),
#  ('vmp.reports.vulnerability.port_audit', 'Port Audit'),
#  ('vmp.reports.vulnerability.port_audit_DESC',
#   'This table contains all the ports that are utilized by application/services running in your systems.'),
#  ('dc.js.common.CUSTOM_FIELDS', 'Custom Fields'),
#  ('dc.js.common.SEARCH_HISTORY', 'Search History'),
#  ('dc.js.common.PATCH_COMP_NAME', 'Patch Computer Name'),
#  ('dc.js.common.SOM_COMP_NAME', 'SoM Computer Name'),
#  ('dc.js.common.BULLETIN_ID', 'Bulletin Id'),
#  ('smp.common.tabcomponent.threats', 'Threats'),
#  ('smp.common.smart_view', 'Smart View'),
#  ('smp.common.view_more', 'View more'),
#  ('smp.common.no_data_found_for_search', 'No Data found for your search'),
#  ('smp.common.systems_affected', 'system(s) affected'),
#  ('smp.common.affected_resources', 'Affected System(s)'),
#  ('smp.common.fix', 'Deploy Secure Configuration'),
#  ('smp.common.fix_now', 'Fix Now'),
#  ('smp.common.copyright', 'Copyright 2019, ZOHO Corp.'),
#  ('smp.common.active_sessions', 'Active Session(s)'),
#  ('smp.common.crop_current_photo', 'Crop Current Photo'),
#  ('smp.common.min_dimensions', 'Minimum dimensions 100*100 px'),
#  ('smp.common.trial_expires_in',
#   'Explore Vulnerability Manager Plus at its best, unlimited for {trial} days.'),
#  ...]

# %%
test = "test"
path = r'C:\Users\harish-4072\Pictures\ApplicationResources.properties'
